# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
df=pd.read_csv(r"/Users/saint/Downloads/adult_eda.csv")
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm         12.000
# 32557   40           Private  154374     HS-grad          9.000
# 32558   58           Private  151910     HS-grad          9.000
# 32559   22           Private  201490     HS-grad          9.000
# 32560   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
df.duplicated().value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().value_counts()
# Out:
# False    32537
# dtype: int64

# %%
df.describe(include='all')
# Out:
#              age workclass      fnlwgt education  education-num  \
# count  32537.000     32537   32537.000     32537      31735.000
# unique       NaN         9         NaN        16            NaN
# top          NaN   Private         NaN   HS-grad            NaN
# freq         NaN     22673         NaN     10494            NaN
# mean      38.586       NaN  189780.849       NaN         10.084
# std       13.638       NaN  105556.471       NaN          2.575
# min       17.000       NaN   12285.000       NaN          1.000
# 25%       28.000       NaN  117827.000       NaN          9.000
# 50%       37.000       NaN  178356.000       NaN         10.000
# 75%       48.000       NaN  236993.000       NaN         12.000
# max       90.000       NaN 1484705.000       NaN         16.000
#
#             marital-status      occupation relationship   race    sex  \
# count                32537           32537        27473  32537  32537
# ...

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5064
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education-num     2.465
# marital-status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# sex               0.000
# capital-gain      0.000
# capital-loss      0.000
# hours-per-week    0.000
# native-country    0.000
# salary            0.000
# dtype: float64

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
df.count()
# Out:
# age               32537
# workclass         32537
# fnlwgt            32537
# education         32537
# education-num     31735
# marital-status    32537
# occupation        32537
# relationship      27473
# race              32537
# sex               32537
# capital-gain      32537
# capital-loss      32537
# hours-per-week    32537
# native-country    32537
# salary            32537
# dtype: int64

# %%
df.count().index
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
df.describe(include ='number')
# Out:
#             age      fnlwgt  education-num  capital-gain  capital-loss  \
# count 32537.000   32537.000      31735.000     32537.000     32537.000
# mean     38.586  189780.849         10.084      1078.444        87.368
# std      13.638  105556.471          2.575      7387.957       403.102
# min      17.000   12285.000          1.000         0.000         0.000
# 25%      28.000  117827.000          9.000         0.000         0.000
# 50%      37.000  178356.000         10.000         0.000         0.000
# 75%      48.000  236993.000         12.000         0.000         0.000
# max      90.000 1484705.000         16.000     99999.000      4356.000
#
#        hours-per-week
# count       32537.000
# mean           40.440
# std            12.347
# min             1.000
# 25%            40.000
# 50%            40.000
# 75%            45.000
# max            99.000

# %%
df.describe(include ='object')
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      32537     32537               32537           32537        27473
# unique         9        16                   7              15            5
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22673     10494               14970            4136        13187
#
#          race    sex native-country salary
# count   32537  32537          32537  32537
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27795  21775          29153  24698

# %%
object_col = df.select_dtypes(include='object').columns #bunu bilmiyorum, soralım lütfen....
object_col
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country', 'salary'],
#       dtype='object')

# %%
for col in object_col:
    print(col)
    print("--"*8)
    print(df[col].value_counts(dropna=False))
    print("--"*20)
# Out:
# workclass
# ----------------
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ----------------------------------------
# education
# ----------------
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64
# ----------------------------------------
# marital-status
# ----------------
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# ...

# %%
df.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %% [markdown]
# # Target_Feature

# %% [markdown]
# # 01_Salary

# %%
df.salary.value_counts()
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
fig, ax = plt.subplots()

ax=sns.countplot(x="salary", data=df)
ax.set_title("Percentage of Income Levels")
for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x()+0.3, p.get_height()+20))

# %%
fig, ax=plt.subplots(figsize=(5,5))

explode = (0, 0.1)
ax.pie(x=df.salary.value_counts().values, labels=df.salary.value_counts().index,
      explode=explode,
      autopct="%.1f%%")
ax.set_title("Percentage of Income Levels")

plt.show()

# %% [markdown]
# # Numeric Features

# %% [markdown]
# # 02_AGE

# %%
sns.boxplot(x="age", data=df);

# %%
sns.histplot(x="age", data=df, kde=True, bins=10)
plt.show()

# %%
df.age.describe()
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %%
sns.boxplot(x="salary", y="age", data=df);

# %%
sns.histplot(x="age", data=df, kde=True, hue="salary", bins=10);

# %%
sns.kdeplot(x="age", data=df, hue="salary",fill=True);

# %%
df.groupby("salary")["age"].describe()
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %% [markdown]
# # 03_fnlwgt
# this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights. There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)

# %%
sns.boxplot(x="fnlwgt", data=df);

# %%
sns.histplot(x="fnlwgt", data=df, kde=True);

# %%
df.fnlwgt.sort_values(ascending=True)
# Out:
# 17096      12285
# 27207      13769
# 25743      14878
# 24012      18827
# 10826      19214
#           ...
# 8258     1226583
# 15569    1268339
# 16739    1366120
# 18138    1455435
# 14449    1484705
# Name: fnlwgt, Length: 32537, dtype: int64

# %%
df.fnlwgt
# Out:
# 0         77516
# 1         83311
# 2        215646
# 3        234721
# 4        338409
#           ...
# 32556    257302
# 32557    154374
# 32558    151910
# 32559    201490
# 32560    287927
# Name: fnlwgt, Length: 32537, dtype: int64

# %%
sns.kdeplot(x="fnlwgt", data=df, fill=True); #1e6 is stands for 1 million.

# %%
df.fnlwgt.describe()
# Out:
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %%
sns.boxplot(x="salary", y="fnlwgt", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='fnlwgt'>

# %%
sns.histplot(x="fnlwgt", data=df, kde=True, hue="salary", fill=True);

# %%
sns.kdeplot(x="fnlwgt", data=df, hue="salary", fill=True);

# %%
df.groupby("salary")["fnlwgt"].describe()
# Out:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24698.000 190345.927 106487.413 12285.000 117606.000 179465.000
# >50K    7839.000 188000.481 102554.464 14878.000 119100.000 176063.000
#
#               75%         max
# salary
# <=50K  238968.250 1484705.000
# >50K   230969.000 1226583.000

# %% [markdown]
# # 04_CAPITAL_GAIN

# %%
sns.boxplot(x="capital-gain", data=df);

# %%
sns.kdeplot(x="capital-gain", data=df, fill=True);

# %%
df["capital-gain"].describe() # df.capital-gain tanımıyor, çalışmıyor.
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital-gain, dtype: float64

# %%
sns.boxplot(x="salary", data=df, y="capital-gain");

# %%
sns.kdeplot(x="capital-gain", data=df, hue="salary");

# %%
df.groupby("salary")["capital-gain"].describe()
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %%
df[df["capital-gain"]!=0].groupby("salary")["capital-gain"].describe()
# Out:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %%
df2=df[df["capital-gain"]!=0]
df2
# Out:
#        age         workclass  fnlwgt    education  education-num  \
# 0       39         State-gov   77516    Bachelors         13.000
# 8       31           Private   45781      Masters         14.000
# 9       42           Private  159449    Bachelors         13.000
# 59      30           Private  188146      HS-grad          9.000
# 60      30           Private   59496    Bachelors         13.000
# ...    ...               ...     ...          ...            ...
# 32515   66       Federal-gov   47358         10th          6.000
# 32518   57         Local-gov  110417      HS-grad          9.000
# 32538   38           Private  139180    Bachelors         13.000
# 32548   65  Self-emp-not-inc   99359  Prof-school         15.000
# 32560   52      Self-emp-inc  287927      HS-grad          9.000
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df2.groupby("salary")["capital-gain"].describe()
# Out:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %% [markdown]
# # 05_CAPITAL_LOSS

# %%
sns.boxplot(x="capital-loss", data=df);

# %%
sns.kdeplot(x="capital-loss", data=df, fill=True);

# %%
df["capital-loss"].describe()
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital-loss, dtype: float64

# %%
sns.boxplot(x="salary", y="capital-loss", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='capital-loss'>

# %%
sns.kdeplot(x="capital-loss", data=df, fill=True, hue="salary");

# %%
df.groupby("salary")["capital-loss"].describe()
# Out:
#            count    mean     std   min   25%   50%   75%      max
# salary
# <=50K  24698.000  53.190 310.890 0.000 0.000 0.000 0.000 4356.000
# >50K    7839.000 195.051 595.555 0.000 0.000 0.000 0.000 3683.000

# %%
df[df["capital-loss"]!=0].groupby("salary")["capital-loss"].describe()
# Out:
#          count     mean     std     min      25%      50%      75%      max
# salary
# <=50K  746.000 1760.983 438.906 155.000 1590.000 1721.000 1980.000 4356.000
# >50K   773.000 1978.017 264.144 653.000 1887.000 1902.000 1977.000 3683.000

# %% [markdown]
# # 06_Hours_Per_Week

# %%
df.head(1)
# Out:
#    age  workclass  fnlwgt  education  education-num marital-status  \
# 0   39  State-gov   77516  Bachelors         13.000  Never-married
#
#      occupation   relationship   race   sex  capital-gain  capital-loss  \
# 0  Adm-clerical  Not-in-family  White  Male          2174             0
#
#    hours-per-week native-country salary
# 0              40  United-States  <=50K

# %%
sns.boxplot(x="hours-per-week", data=df);

# %%
sns.kdeplot(x="hours-per-week", data=df, fill=True);

# %%
df["hours-per-week"].describe()
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours-per-week, dtype: float64

# %%
sns.boxplot(x="salary", y="hours-per-week", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='hours-per-week'>

# %%
sns.kdeplot(x="hours-per-week", data=df, fill=True, hue="salary");

# %%
df.groupby("salary")["hours-per-week"].describe()
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %%
sns.pairplot(df, hue="salary", corner=True);

# %% [markdown]
# # Categorical Features

# %% [markdown]
# # 07_Education
# # 08_Education_Num

# %%
df.education.value_counts()
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
df["education-num"].value_counts()
# Out:
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education-num, dtype: int64

# %%
df.groupby("education")["education-num"].value_counts(dropna=False)
# Out:
# education     education-num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# ...

# %%
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.barplot(x=df["education"].value_counts().index, y=df["education"].value_counts().values, data=df)
ax.set_xticklabels(df["education"].value_counts().index, rotation=90)
ax.set_xlabel("education")
ax.set_ylabel("count");

# %%
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.barplot(x=df["education-num"].value_counts().index, y=df["education-num"].value_counts().values, data=df)
ax.set_xlabel("education")
ax.set_ylabel("count");

# %%
df.groupby("education")["salary"].value_counts()
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# ...

# %%
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.countplot(x="education", data=df, hue="salary")

# %%
df.groupby("education-num")["salary"].value_counts()
# Out:
# education-num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
# ...

# %%
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.countplot(x="education-num", data=df, hue="salary");

# %%
sns.boxplot(x="salary", y="education-num", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='education-num'>

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"
df["education_summary"]= df.education.apply(mapping_education)

# %%
df.education_summary.value_counts()
# Out:
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: education_summary, dtype: int64

# %%
df.drop("education_new", axis=1, inplace=True)

# %%
sns.countplot(x="education_summary", data=df)
# Out:
# <AxesSubplot:xlabel='education_summary', ylabel='count'>

# %%
df.groupby("education_summary")["salary"].value_counts()
# Out:
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
sns.countplot(x="education_summary", data=df, hue="salary");

# %%
fig, ax=plt.subplots(figsize=(5,5))

explode = (0, 0, 0)
ax.pie(x=df["education_summary"].value_counts().values, labels=df["education_summary"].value_counts().index,
      explode=explode,
      autopct="%.1f%%")

plt.show()

# %%
df.groupby("education_summary")["salary"].value_counts()/df.groupby("education_summary")["salary"].count()
# Out:
# education_summary   salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# Name: salary, dtype: float64

# %%
fig, ax=plt.subplots(figsize=(3,3))
ax.pie(x=df.groupby("education_summary")["salary"].value_counts().high_level_grade.values, labels=df.groupby("education_summary")["salary"].value_counts().high_level_grade.index,
      autopct="%.1f%%")
ax.set_title("high_level_grade")
plt.show()

fig, ax=plt.subplots(figsize=(3,3))
ax.pie(x=df.groupby("education_summary")["salary"].value_counts().low_level_grade.values, labels=df.groupby("education_summary")["salary"].value_counts().low_level_grade.index,
      autopct="%.1f%%")
ax.set_title("low_level_grade")
plt.show()

fig, ax=plt.subplots(figsize=(3,3))
ax.pie(x=df.groupby("education_summary")["salary"].value_counts().medium_level_grade, labels=df.groupby("education_summary")["salary"].value_counts().medium_level_grade.index,
      autopct="%.1f%%")
ax.set_title("medium_level_grade")
plt.show()

# %%
df.groupby("salary")["education_summary"].value_counts()
# Out:
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
sns.countplot(x="salary", data=df, hue="education_summary");

# %%
df.groupby("salary")["education_summary"].value_counts(normalize=True)
# Out:
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: education_summary, dtype: float64

# %%
df_education=df.groupby("salary")["education_summary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
df_education
# Out:
#   salary   education_summary  percentage
# 0  <=50K  medium_level_grade       0.670
# 1  <=50K    high_level_grade       0.168
# 2  <=50K     low_level_grade       0.162
# 3   >50K    high_level_grade       0.499
# 4   >50K  medium_level_grade       0.470
# 5   >50K     low_level_grade       0.031

# %% [markdown]
# # 09_marital_status
# # 10_ relationship

# %%
df["marital-status"].value_counts(dropna=False)
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %%
df["relationship"].value_counts(dropna=False)
# Out:
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
df.relationship.fillna("Unknown",inplace=True)

# %%
df.groupby("relationship")["marital-status"].value_counts(dropna=False)
# Out:
# relationship    marital-status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unknown         Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
# ...

# %%
sns.countplot(x="marital-status", data=df);

# %%
df.groupby("marital-status")["salary"].value_counts()
# Out:
# marital-status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
sns.countplot(x="marital-status", data=df, hue="salary");

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"
df["marital_status_summary"]=df["marital-status"].apply(mapping_marital_status)

# %%
df.marital_status_summary.value_counts()
# Out:
# unmarried    17126
# married      15411
# Name: marital_status_summary, dtype: int64

# %%
sns.countplot(x="marital_status_summary", data=df);

# %%
df.groupby("marital_status_summary").salary.value_counts()
# Out:
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
sns.countplot(x="marital_status_summary", data=df, hue="salary");

# %%
df.groupby("marital_status_summary").salary.value_counts()/df.groupby("marital_status_summary").salary.count()
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
fig = plt.figure(figsize=(5,4),dpi=98)
ax = fig.add_subplot(121)
cts = df.groupby("marital_status_summary").salary.value_counts().married
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%")
ax.set_title("married");

ax = fig.add_subplot(122)
cts = df.groupby("marital_status_summary").salary.value_counts().unmarried
ax.pie(cts,labels=cts.index,
      autopct="%.1f%%")
ax.set_title("unmarried");

# %%
df.groupby("marital_status_summary").salary.value_counts().married.index
# Out:
# Index(['<=50K', '>50K'], dtype='object', name='salary')

# %%
df.groupby("salary").marital_status_summary.value_counts()
# Out:
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %%
sns.countplot(x="salary", data=df, hue="marital_status_summary");

# %%
df.groupby("salary").marital_status_summary.value_counts()/df.groupby("salary").marital_status_summary.count()
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %% [markdown]
# # pie plot for each salary level by marital_status_summary
#
# fig, ax=plt.subplots(figsize=(15,7), nrows=1, ncols=2)
# color=["#ffa3b1","#77d2fc"]
# ax[0].pie(x=df_sal_perc["percentage"]["<=50K"], labels=df_sal_perc.index, autopct="%.2f%%", colors=color)
# ax[0].set_title("<=50K")
# ax[0].set_ylabel("percentage")
#
# ax[1].pie(x=df_sal_perc["percentage"][">50K"], labels=df_sal_perc.index, autopct="%.2f%%", colors=color)
# ax[1].set_title(">50K")
# ax[1].set_ylabel("percentage");

# %%
fig = plt.figure(figsize=(5,4),dpi=98)
ax = fig.add_subplot(121)

cts = df.groupby("salary").marital_status_summary.value_counts()["<=50K"]
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%")
ax.set_title("<=50K");

ax = fig.add_subplot(122)
cts = df.groupby("salary").marital_status_summary.value_counts()[">50K"]
ax.pie(cts,labels=cts.index,
      autopct="%.1f%%")
ax.set_title(">50K");

# %% [markdown]
# # 11_WORKCLASS

# %%
df.workclass.value_counts(dropna=False)
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
sns.countplot(x="workclass", data=df);

# %%
df.workclass.replace(to_replace=["?"], value="Unknown",inplace=True)

# %%
df.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df.groupby("workclass").salary.value_counts()
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
sns.countplot(x="workclass", data=df, hue="salary");

# %%
df.groupby("workclass").salary.value_counts(normalize=True)
# Out:
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknown           <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: salary, dtype: float64

# %% [markdown]
# df.groupby("workclass").salary.value_counts(normalize=True).to_frame(name="percentage").reset_index()

# %%
df_work=df.groupby("workclass").salary.value_counts(normalize=True).to_frame(name="percentage").reset_index()
df_work
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 7       Self-emp-inc   >50K       0.557
# 8       Self-emp-inc  <=50K       0.443
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13           Unknown  <=50K       0.896
# 14           Unknown   >50K       0.104
# 15       Without-pay  <=50K       1.000

# %%
sns.barplot(x="workclass", y="percentage", data=df_work, hue="salary");

# %%
df.groupby("salary").workclass.value_counts()
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
sns.countplot(x="salary", data=df, hue="workclass")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %%
df.groupby("salary")["workclass"].value_counts()
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
df.groupby("salary")["workclass"].value_counts(normalize=True)
# Out:
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknown            0.024
# Name: workclass, dtype: float64

# %%
df_work2=df.groupby("salary")["workclass"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
df_work2
# Out:
#    salary         workclass  percentage
# 0   <=50K           Private       0.717
# 1   <=50K  Self-emp-not-inc       0.074
# 2   <=50K           Unknown       0.067
# 3   <=50K         Local-gov       0.060
# 4   <=50K         State-gov       0.038
# 5   <=50K       Federal-gov       0.024
# 6   <=50K      Self-emp-inc       0.020
# 7   <=50K       Without-pay       0.001
# 8   <=50K      Never-worked       0.000
# 9    >50K           Private       0.633
# 10   >50K  Self-emp-not-inc       0.092
# 11   >50K      Self-emp-inc       0.079
# 12   >50K         Local-gov       0.079
# 13   >50K       Federal-gov       0.047
# 14   >50K         State-gov       0.045
# 15   >50K           Unknown       0.024

# %%
sns.barplot(x="salary", y="percentage", hue="workclass", data=df_work2);

# %% [markdown]
# # occupation

# %%
df.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
ax=sns.countplot(x="occupation", data=df)
ax.tick_params(axis="x", rotation=90);

# %%
df.occupation.replace(to_replace=["?"], value="Unknown",inplace=True)

# %%
df.groupby("occupation")["salary"].value_counts()
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
# ...

# %%
ax=sns.countplot(x="occupation", data=df, hue="salary")
ax.tick_params(axis="x", rotation=90);

# %%
df.groupby("occupation")["salary"].value_counts(normalize=True)
# Out:
# occupation         salary
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
# ...

# %%
df_occ=df.groupby("occupation")["salary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
df_occ
# Out:
#            occupation salary  percentage
# 0        Adm-clerical  <=50K       0.865
# 1        Adm-clerical   >50K       0.135
# 2        Armed-Forces  <=50K       0.889
# 3        Armed-Forces   >50K       0.111
# 4        Craft-repair  <=50K       0.773
# 5        Craft-repair   >50K       0.227
# 6     Exec-managerial  <=50K       0.516
# 7     Exec-managerial   >50K       0.484
# 8     Farming-fishing  <=50K       0.884
# 9     Farming-fishing   >50K       0.116
# 10  Handlers-cleaners  <=50K       0.937
# 11  Handlers-cleaners   >50K       0.063
# 12  Machine-op-inspct  <=50K       0.875
# 13  Machine-op-inspct   >50K       0.124
# 14      Other-service  <=50K       0.958
# 15      Other-service   >50K       0.042
# 16    Priv-house-serv  <=50K       0.993
# 17    Priv-house-serv   >50K       0.007
# 18     Prof-specialty  <=50K       0.551
# 19     Prof-specialty   >50K       0.449
# 20    Protective-serv  <=50K       0.675
# 21    Protective-serv   >50K       0.325
# ...

# %%
ax=sns.barplot(x="occupation", y="percentage", data=df_occ, hue="salary")
ax.tick_params(axis="x", rotation=90)

# %%
df.groupby("salary")["occupation"].value_counts()
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
# ...

# %%
sns.countplot(x="salary", data=df, hue="occupation");

# %%
df.groupby("salary")["occupation"].value_counts(normalize=True)
# Out:
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unknown             0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unknown             0.024
#         Other-service       0.017
#         Farming-fishing     0.015
# ...

# %%
df_occ2=df.groupby("salary")["occupation"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
df_occ2
# Out:
#    salary         occupation  percentage
# 0   <=50K       Adm-clerical       0.132
# 1   <=50K       Craft-repair       0.128
# 2   <=50K      Other-service       0.128
# 3   <=50K              Sales       0.108
# 4   <=50K     Prof-specialty       0.092
# 5   <=50K    Exec-managerial       0.085
# 6   <=50K  Machine-op-inspct       0.071
# 7   <=50K            Unknown       0.067
# 8   <=50K  Handlers-cleaners       0.052
# 9   <=50K   Transport-moving       0.052
# 10  <=50K    Farming-fishing       0.036
# 11  <=50K       Tech-support       0.026
# 12  <=50K    Protective-serv       0.018
# 13  <=50K    Priv-house-serv       0.006
# 14  <=50K       Armed-Forces       0.000
# 15   >50K    Exec-managerial       0.251
# 16   >50K     Prof-specialty       0.237
# 17   >50K              Sales       0.125
# 18   >50K       Craft-repair       0.119
# 19   >50K       Adm-clerical       0.065
# 20   >50K   Transport-moving       0.041
# 21   >50K       Tech-support       0.036
# ...

# %%
sns.barplot(x="salary", y="percentage", data=df_occ2, hue="occupation")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='percentage'>

# %% [markdown]
# # 12_Race

# %%
df.race.value_counts()
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
sns.countplot(x="race", data=df);

# %%
df.groupby("race")["salary"].value_counts()
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
ax=sns.countplot(x="race", data=df, hue="salary")
ax.tick_params(axis="x", rotation=90)

# %%
df_race=df.groupby("race")["salary"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
df_race
# Out:
#                  race salary  percentage
# 0  Amer-Indian-Eskimo  <=50K       0.884
# 1  Amer-Indian-Eskimo   >50K       0.116
# 2  Asian-Pac-Islander  <=50K       0.734
# 3  Asian-Pac-Islander   >50K       0.266
# 4               Black  <=50K       0.876
# 5               Black   >50K       0.124
# 6               Other  <=50K       0.908
# 7               Other   >50K       0.092
# 8               White  <=50K       0.744
# 9               White   >50K       0.256

# %%
df_race.race.value_counts().index
# Out:
# Index(['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other', 'White'], dtype='object')

# %%
fig = plt.figure(figsize=(12,8),dpi=98)
color=["#ffa3b1","#77d2fc"]
ax = fig.add_subplot(231)
cts = df.groupby("race").salary.value_counts()["Amer-Indian-Eskimo"]
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%", colors=color)
ax.set_title("Amer-Indian-Eskimo");

ax = fig.add_subplot(232)
cts = df.groupby("race").salary.value_counts()["Asian-Pac-Islander"]
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%", colors=color)
ax.set_title("Asian-Pac-Islander");

ax = fig.add_subplot(233)
cts = df.groupby("race").salary.value_counts().Black
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%", colors=color)
ax.set_title("Black");

ax = fig.add_subplot(234)
cts = df.groupby("race").salary.value_counts().Other 
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%", colors=color)
ax.set_title("Other");

ax = fig.add_subplot(235)
cts = df.groupby("race").salary.value_counts().White
ax.pie(cts, labels=cts.index,
      autopct="%.1f%%", colors=color)
ax.set_title("White");

# %%
df.groupby("salary")["race"].value_counts()
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
sns.countplot(x="salary", hue="race", data=df);

# %%
df.groupby("salary")["race"].value_counts(normalize=True)
# Out:
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
df.groupby("salary")["race"].value_counts(normalize=True).to_frame(name="percentage").reset_index()
# Out:
#   salary                race  percentage
# 0  <=50K               White       0.837
# 1  <=50K               Black       0.111
# 2  <=50K  Asian-Pac-Islander       0.031
# 3  <=50K  Amer-Indian-Eskimo       0.011
# 4  <=50K               Other       0.010
# 5   >50K               White       0.908
# 6   >50K               Black       0.049
# 7   >50K  Asian-Pac-Islander       0.035
# 8   >50K  Amer-Indian-Eskimo       0.005
# 9   >50K               Other       0.003

# %%
sns.countplot(x="salary", hue="race", data=df);

# %% [markdown]
# # 13_gender

# %%
df.sex.value_counts()
# Out:
# Male      21775
# Female    10762
# Name: sex, dtype: int64

# %%
sns.countplot(x="sex", data=df);

# %%
df.groupby("sex")["salary"].value_counts()
# Out:
# sex     salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
sns.countplot(x="sex", hue="salary", data=df);

# %%
df.groupby("sex")["salary"].value_counts(normalize=True)
# Out:
# sex     salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
df.groupby("salary")["sex"].value_counts()
# Out:
# salary  sex
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: sex, dtype: int64

# %%
sns.countplot(x="salary", hue="sex", data=df);

# %%
df.groupby("salary")["sex"].value_counts(normalize=True)
# Out:
# salary  sex
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: sex, dtype: float64

# %% [markdown]
# # 14_Native_Country

# %%
df["native-country"].value_counts()
# Out:
# United-States                 29153
# Mexico                          639
# Unknown                         582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
ax=sns.countplot(x="native-country", data=df)
ax.tick_params(axis="x", rotation=90)

# %%
df["native-country"].replace(to_replace=["?"],value="Unknown", inplace=True)

# %%
def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"
df["native_country_summary"]=df["native-country"].apply(mapping_native_country)

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.native_country_summary.value_counts()
# Out:
# US        29153
# Others     3384
# Name: native_country_summary, dtype: int64

# %%
ax=sns.countplot(x="native_country_summary", data=df);

# %%
df.groupby("native_country_summary")["salary"].value_counts()
# Out:
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: salary, dtype: int64

# %%
sns.countplot(x="native_country_summary", data=df, hue="salary")
# Out:
# <AxesSubplot:xlabel='native_country_summary', ylabel='count'>

# %%
df.groupby("native_country_summary")["salary"].value_counts(normalize=True)
# Out:
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: salary, dtype: float64

# %%
df.groupby("salary")["native_country_summary"].value_counts()
# Out:
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: native_country_summary, dtype: int64

# %%
sns.countplot(x="salary", data=df, hue="native_country_summary")
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %%
df.groupby("salary")["native_country_summary"].value_counts(normalize=True)
# Out:
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: native_country_summary, dtype: float64

# %%
df.plot()

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %%
df.head(2)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
#
#        marital-status       occupation   relationship   race   sex  \
# 0       Never-married     Adm-clerical  Not-in-family  White  Male
# 1  Married-civ-spouse  Exec-managerial        Husband  White  Male
#
#    capital-gain  capital-loss  hours-per-week native-country salary  \
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
#
#   education_summary marital_status_summary native_country_summary
# 0  high_level_grade              unmarried                     US
# 1  high_level_grade                married                     US

# %%
df.groupby(["salary","sex"]).age.mean()
# Out:
# salary  sex
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %%
ax = df.groupby(["salary", "sex"])["age"].mean().plot(kind="bar")
for i in ax.containers:
    ax.bar_label(i, fmt="%.2f")

# %%
df_1=df.groupby(["salary","sex"]).age.mean().to_frame(name="avrage").reset_index()
df_1
# Out:
#   salary     sex  avrage
# 0  <=50K  Female  36.217
# 1  <=50K    Male  37.149
# 2   >50K  Female  42.126
# 3   >50K    Male  44.627

# %%
ax=sns.barplot(x="salary", y="avrage", hue="sex", data=df_1)
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1]);

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %%
df["workclass"][(df["salary"]==">50K")&(df["native_country_summary"]=="US")].value_counts(normalize=True)
# Out:
# Private            0.633
# Self-emp-not-inc   0.092
# Local-gov          0.080
# Self-emp-inc       0.078
# Federal-gov        0.047
# State-gov          0.045
# Unknown            0.025
# Name: workclass, dtype: float64

# %%
df_2["percentage_new"]= df_2["percentage"]*100
df_2
# Out:
#               index  percentage  percentage_new
# 0           Private       0.633          63.314
# 1  Self-emp-not-inc       0.092           9.192
# 2         Local-gov       0.080           8.021
# 3      Self-emp-inc       0.078           7.784
# 4       Federal-gov       0.047           4.687
# 5         State-gov       0.045           4.547
# 6           Unknown       0.025           2.455

# %%
# df_2.rename(columns={"index":"workclass"})
df_2.columns = ["workclass", "percentage", "percentage_new"]
df_2
# Out:
#           workclass  percentage  percentage_new
# 0           Private       0.633          63.314
# 1  Self-emp-not-inc       0.092           9.192
# 2         Local-gov       0.080           8.021
# 3      Self-emp-inc       0.078           7.784
# 4       Federal-gov       0.047           4.687
# 5         State-gov       0.045           4.547
# 6           Unknown       0.025           2.455

# %%
sns.barplot(x="workclass", y="percentage", data=df_2);

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
df_3=df["occupation"][(df["workclass"]=="Private") & (df["salary"]==">50K")& (df["native_country_summary"]=="US")].value_counts(normalize=True)*100

# %%
df_33=df_3.to_frame(name="percentage").reset_index()
df_33
# Out:
#                 index  percentage
# 0     Exec-managerial      26.438
# 1      Prof-specialty      19.476
# 2        Craft-repair      14.695
# 3               Sales      14.475
# 4        Adm-clerical       6.389
# 5    Transport-moving       5.442
# 6        Tech-support       4.428
# 7   Machine-op-inspct       4.428
# 8       Other-service       1.674
# 9   Handlers-cleaners       1.344
# 10    Farming-fishing       0.595
# 11    Protective-serv       0.595
# 12    Priv-house-serv       0.022

# %%
df_34=df_33.rename(columns={"index":"occupation"})

# %%
ax=sns.barplot(x="occupation", y="percentage", data=df_34)
ax.tick_params(axis="x", rotation=90)
ax.bar_label(ax.containers[0]);

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
df_4=df["education"][(df["race"]=="Asian-Pac-Islander") & (df["salary"]==">50K")].value_counts(normalize=True)*100
df_4
# Out:
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: education, dtype: float64

# %%
df_44=df_4.to_frame(name="percentage").reset_index()
df_44
# Out:
#            index  percentage
# 0      Bachelors      35.145
# 1        Masters      15.580
# 2        HS-grad      12.319
# 3   Some-college      11.957
# 4    Prof-school       9.783
# 5      Doctorate       6.522
# 6      Assoc-voc       3.261
# 7     Assoc-acdm       2.899
# 8        5th-6th       1.087
# 9            9th       0.362
# 10          11th       0.362
# 11          10th       0.362
# 12          12th       0.362

# %%
ax=sns.barplot(x="index", y="percentage", data=df_44)
ax.tick_params(axis="x", rotation=90)
ax.bar_label(ax.containers[0]);

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %%
df_5=df["occupation"][(df["race"]=="Asian-Pac-Islander") & (df["salary"]==">50K")& (df["education"]=="Bachelors")].value_counts(normalize=True)*100
df_5
# Out:
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: occupation, dtype: float64

# %%
df_55= df_5.to_frame(name="percentage").reset_index()
df_55
# Out:
#                 index  percentage
# 0     Exec-managerial      27.835
# 1      Prof-specialty      25.773
# 2        Adm-clerical      12.371
# 3               Sales       9.278
# 4       Other-service       9.278
# 5        Craft-repair       7.216
# 6        Tech-support       3.093
# 7     Protective-serv       2.062
# 8    Transport-moving       1.031
# 9   Machine-op-inspct       1.031
# 10    Farming-fishing       1.031

# %%
ax=sns.barplot(x="index", y="percentage", data=df_55)
ax.tick_params(axis="x", rotation=90)
ax.bar_label(ax.containers[0]);

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
df.head(2)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
#
#        marital-status       occupation   relationship   race   sex  \
# 0       Never-married     Adm-clerical  Not-in-family  White  Male
# 1  Married-civ-spouse  Exec-managerial        Husband  White  Male
#
#    capital-gain  capital-loss  hours-per-week native-country salary  \
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
#
#   education_summary marital_status_summary native_country_summary
# 0  high_level_grade              unmarried                     US
# 1  high_level_grade                married                     US

# %%
sns.catplot(data=tips,
x="day",
y='total_bill’,
kind="bar",
col="smoker",
row="sex")

# %%
sns.catplot(data=df_c,
           x="education_summary",
           y="hours-per-week",
           kind="bar",
           col="marital_status_summary",
           row="native_country_summary",
           hue="sex");

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education-num           31735 non-null  float64
#  5   marital-status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   sex                     32537 non-null  object
#  10  capital-gain            32537 non-null  int64
#  11  capital-loss            32537 non-null  int64
#  12  hours-per-week          32537 non-null  int64
#  13  native-country          32537 non-null  object
# ...

# %%
df_c=df.copy()
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education-num           31735 non-null  float64
#  5   marital-status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   sex                     32537 non-null  object
#  10  capital-gain            32537 non-null  int64
#  11  capital-loss            32537 non-null  int64
#  12  hours-per-week          32537 non-null  int64
#  13  native-country          32537 non-null  object
# ...

# %%
# df_c.drop(["education", "education-num", "relationship","marital-status", "native-country"],axis=1,inplace=True)

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   occupation              32537 non-null  object
#  4   race                    32537 non-null  object
#  5   sex                     32537 non-null  object
#  6   capital-gain            32537 non-null  int64
#  7   capital-loss            32537 non-null  int64
#  8   hours-per-week          32537 non-null  int64
#  9   salary                  32537 non-null  object
#  10  education_summary       32537 non-null  object
#  11  marital_status_summary  32537 non-null  object
#  12  native_country_summary  32537 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 4.5+ MB

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df_c.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital-gain              0
# capital-loss              0
# hours-per-week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %%
# df.isin(["Unknown"]).any()
# Out:
# age                       False
# workclass                  True
# fnlwgt                    False
# education                 False
# education-num             False
# marital-status            False
# occupation                 True
# relationship               True
# race                      False
# sex                       False
# capital-gain              False
# capital-loss              False
# hours-per-week            False
# native-country             True
# salary                    False
# education_summary         False
# marital_status_summary    False
# native_country_summary    False
# dtype: bool

# %%
df_c.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df_c.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df_c["workclass"]=df_c.workclass.replace(to_replace="Unknown", value=np.nan).astype("object")

# %%
df_c.workclass.value_counts(dropna=False)
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# NaN                  1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df_c["occupation"]=df_c.occupation.replace(to_replace="Unknown",value=np.nan).astype("object")

# %%
df_c.isnull().sum()
# Out:
# age                          0
# workclass                 1836
# fnlwgt                       0
# occupation                1843
# race                         0
# sex                          0
# capital-gain                 0
# capital-loss                 0
# hours-per-week               0
# salary                       0
# education_summary            0
# marital_status_summary       0
# native_country_summary       0
# dtype: int64

# %%
df_c.dropna(inplace=True)

# %%
df_c.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital-gain              0
# capital-loss              0
# hours-per-week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30694 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     30694 non-null  int64
#  1   workclass               30694 non-null  object
#  2   fnlwgt                  30694 non-null  int64
#  3   occupation              30694 non-null  object
#  4   race                    30694 non-null  object
#  5   sex                     30694 non-null  object
#  6   capital-gain            30694 non-null  int64
#  7   capital-loss            30694 non-null  int64
#  8   hours-per-week          30694 non-null  int64
#  9   salary                  30694 non-null  object
#  10  education_summary       30694 non-null  object
#  11  marital_status_summary  30694 non-null  object
#  12  native_country_summary  30694 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 3.3+ MB

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df_c.plot(kind="box");

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(231)
sns.boxplot(x="age", data=df_c)

ax = fig.add_subplot(232)
sns.boxplot(x="fnlwgt", data=df_c)

ax = fig.add_subplot(233)
sns.boxplot(x="capital-gain", data=df_c)

ax = fig.add_subplot(234)

sns.boxplot(x="capital-loss", data=df_c)

ax = fig.add_subplot(235)
sns.boxplot(x="hours-per-week", data=df_c)

plt.tight_layout()

# %%
# Your Code is Here

fig, ax = plt.subplots(nrows=5, ncols=2, figsize=(20,30))
sns.boxplot(ax=ax[0,0],x="age", data=df)
sns.boxplot(ax=ax[1,0],x="fnlwgt", data=df)
sns.boxplot(ax=ax[2,0],x="capital-gain", data=df)
sns.boxplot(ax=ax[3,0],x="capital-loss", data=df)
sns.boxplot(ax=ax[4,0],x="hours-per-week", data=df)

sns.histplot(ax=ax[0,1],x="age", data=df)
sns.histplot(ax=ax[1,1],x="fnlwgt", data=df)
sns.histplot(ax=ax[2,1],x="capital-gain", data=df)
sns.histplot(ax=ax[3,1],x="capital-loss", data=df)
sns.histplot(ax=ax[4,1],x="hours-per-week", data=df)
# Out:
# <AxesSubplot:xlabel='hours-per-week', ylabel='Count'>

# %%
df_stat=df_c.describe(include="number").T
df_stat
# Out:
#                    count       mean        std       min        25%  \
# age            30694.000     38.448     13.115    17.000     28.000
# fnlwgt         30694.000 189848.229 105465.126 13769.000 117828.500
# capital-gain   30694.000   1106.902   7500.730     0.000      0.000
# capital-loss   30694.000     88.980    405.808     0.000      0.000
# hours-per-week 30694.000     40.953     11.984     1.000     40.000
#
#                       50%        75%         max
# age                37.000     47.000      90.000
# fnlwgt         178513.500 237293.750 1484705.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(121)
sns.boxplot(x="age", data=df_c)

ax = fig.add_subplot(122)
sns.histplot(x="age", data=df_c);

# %%
Q1 = df_c["age"].quantile(0.25)
Q3 = df_c["age"].quantile(0.75)

IQR = Q3 - Q1

print(Q1,Q3,IQR)
# Out:
# 28.0 47.0 19.0

# %%
lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 1.5 * IQR
print (lower_lim, upper_lim)
# Out:
# -0.5 75.5

# %%
df_c.loc[(df_c.age < lower_lim) | (df_c.age > upper_lim)].sort_values(by="age", ascending=False)
# Out:
#        age         workclass  fnlwgt       occupation                race  \
# 8806    90           Private   87372   Prof-specialty               White
# 14159   90         Local-gov  187749     Adm-clerical  Asian-Pac-Islander
# 28463   90       Federal-gov  195433     Craft-repair               White
# 12975   90           Private  250832  Exec-managerial               White
# 11996   90           Private   40388  Exec-managerial               White
# ...    ...               ...     ...              ...                 ...
# 15102   76         Local-gov  169133     Adm-clerical               White
# 19085   76           Private  125784  Exec-managerial               White
# 23515   76           Private  142535     Adm-clerical               White
# 8240    76  Self-emp-not-inc  225964            Sales               White
# 23354   76           Private  199949     Adm-clerical               White
#
#           sex  capital-gain  capital-loss  hours-per-week salary  \
# ...

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(121)
sns.boxplot(x="hours-per-week", data=df_c)

ax = fig.add_subplot(122)
sns.histplot(x="hours-per-week", data=df_c);

# %%
Q1 = df_c["hours-per-week"].quantile(0.25)
Q3 = df_c["hours-per-week"].quantile(0.75)

IQR = Q3 - Q1

print(Q1,Q3,IQR)
# Out:
# 40.0 45.0 5.0

# %%
lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 1.5 * IQR
print (lower_lim, upper_lim)
# Out:
# 32.5 52.5

# %%
df_c.loc[(df_c["hours-per-week"] > upper_lim)].sort_values(by="hours-per-week", ascending=False)
# Out:
#        age         workclass  fnlwgt        occupation   race     sex  \
# 25986   44         Local-gov  212665   Protective-serv  Black    Male
# 19529   38           Private   66326  Transport-moving  White    Male
# 8796    39           Private   70995  Transport-moving  White    Male
# 15534   29           Private  167716     Other-service  White  Female
# 22313   26  Self-emp-not-inc  258306   Farming-fishing  White    Male
# ...    ...               ...     ...               ...    ...     ...
# 1138    27           Private  138705      Craft-repair  White    Male
# 23244   58           Private  248739   Farming-fishing  White    Male
# 28858   62           Private  123411  Transport-moving  White    Male
# 18417   24           Private  117167     Other-service  White  Female
# 31622   61  Self-emp-not-inc  268831             Sales  White    Male
#
#        capital-gain  capital-loss  hours-per-week salary   education_summary  \
# ...

# %%
df_c.loc[(df_c.age > 80)].shape
# Out:
# (76, 13)

# %%
df_c.loc[(df_c.age > 80)].index
# Out:
# Int64Index([  222,   918,  1040,  1168,  1935,  2303,  2891,  2906,  3537,
#              4070,  4834,  5272,  5370,  5406,  6214,  6232,  6624,  6748,
#              7481,  7720,  8381,  8431,  8806,  8973,  9471, 10210, 10545,
#             11238, 11512, 11996, 12830, 12975, 13295, 13696, 13928, 14159,
#             14711, 14756, 15356, 15662, 15892, 16302, 18277, 18413, 18725,
#             18832, 19045, 19172, 19212, 19489, 19495, 19747, 20421, 20463,
#             20610, 21501, 21835, 22220, 22481, 22895, 23459, 24027, 24043,
#             24280, 24395, 24560, 26731, 27795, 28463, 28948, 29594, 31030,
#             31855, 32277, 32367, 32459],
#            dtype='int64')

# %%
df_c.drop(df_c.loc[(df_c.age > 80)].index, axis=0, inplace=True)
df_c
# Out:
#        age         workclass  fnlwgt         occupation   race     sex  \
# 0       39         State-gov   77516       Adm-clerical  White    Male
# 1       50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2       38           Private  215646  Handlers-cleaners  White    Male
# 3       53           Private  234721  Handlers-cleaners  Black    Male
# 4       28           Private  338409     Prof-specialty  Black  Female
# ...    ...               ...     ...                ...    ...     ...
# 32556   27           Private  257302       Tech-support  White  Female
# 32557   40           Private  154374  Machine-op-inspct  White    Male
# 32558   58           Private  151910       Adm-clerical  White  Female
# 32559   22           Private  201490       Adm-clerical  White    Male
# 32560   52      Self-emp-inc  287927    Exec-managerial  White  Female
#
#        capital-gain  capital-loss  hours-per-week salary   education_summary  \
# ...

# %%
df_c.loc[(df_c["hours-per-week"] < 7)|(df_c["hours-per-week"] >70)].sort_values(by="hours-per-week", ascending=False)
# Out:
#        age         workclass  fnlwgt        occupation                race  \
# 22216   45           Private   54260      Craft-repair               White
# 5432    44           Private   83508    Prof-specialty               White
# 19053   27           Private   40295  Transport-moving               White
# 19141   59           Private  106748     Other-service               White
# 19399   39      Self-emp-inc  163057      Craft-repair               White
# ...    ...               ...     ...               ...                 ...
# 20909   77  Self-emp-not-inc   71676      Adm-clerical               White
# 25078   74           Private  260669     Other-service               White
# 19750   23           Private   72887      Craft-repair  Asian-Pac-Islander
# 189     58         State-gov  109567    Prof-specialty               White
# 24284   57  Self-emp-not-inc   56480   Exec-managerial               White
#
#           sex  capital-gain  capital-loss  hours-per-week salary  \
# ...

# %%
df_c.loc[(df_c["hours-per-week"] < 7)|(df_c["hours-per-week"] >70)].sort_values(by="hours-per-week", ascending=False).index
# Out:
# Int64Index([22216,  5432, 19053, 19141, 19399, 19529, 19731, 19997, 20036,
#             21056,
#             ...
#              6180, 29867,  1036, 11451, 22960, 20909, 25078, 19750,   189,
#             24284],
#            dtype='int64', length=621)

# %%
df_c.drop(df_c.loc[(df_c["hours-per-week"] < 7)|(df_c["hours-per-week"] >70)].sort_values(by="hours-per-week", ascending=False).index, axis=0, inplace=True)
df_c
# Out:
#        age         workclass  fnlwgt         occupation   race     sex  \
# 0       39         State-gov   77516       Adm-clerical  White    Male
# 1       50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2       38           Private  215646  Handlers-cleaners  White    Male
# 3       53           Private  234721  Handlers-cleaners  Black    Male
# 4       28           Private  338409     Prof-specialty  Black  Female
# ...    ...               ...     ...                ...    ...     ...
# 32556   27           Private  257302       Tech-support  White  Female
# 32557   40           Private  154374  Machine-op-inspct  White    Male
# 32558   58           Private  151910       Adm-clerical  White  Female
# 32559   22           Private  201490       Adm-clerical  White    Male
# 32560   52      Self-emp-inc  287927    Exec-managerial  White  Female
#
#        capital-gain  capital-loss  hours-per-week salary   education_summary  \
# ...

# %%
df_c.loc[(df_c.age > 60)&(df_c["hours-per-week"]>60)].shape
# Out:
# (23, 13)

# %%
df_c.loc[(df_c.age > 60)&(df_c["hours-per-week"]>60)].index
# Out:
# Int64Index([ 1541,  2154,  2184,  2665,  3101,  5417,  6826,  8066,  9646,
#             12624, 16634, 18367, 19584, 20125, 23399, 23585, 24903, 25910,
#             26625, 27721, 28294, 31342, 32192],
#            dtype='int64')

# %%
df_c.drop(df_c.loc[(df_c.age > 60)&(df_c["hours-per-week"]>60)].index, axis=0, inplace=True)
df_c
# Out:
#        age         workclass  fnlwgt         occupation   race     sex  \
# 0       39         State-gov   77516       Adm-clerical  White    Male
# 1       50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2       38           Private  215646  Handlers-cleaners  White    Male
# 3       53           Private  234721  Handlers-cleaners  Black    Male
# 4       28           Private  338409     Prof-specialty  Black  Female
# ...    ...               ...     ...                ...    ...     ...
# 32556   27           Private  257302       Tech-support  White  Female
# 32557   40           Private  154374  Machine-op-inspct  White    Male
# 32558   58           Private  151910       Adm-clerical  White  Female
# 32559   22           Private  201490       Adm-clerical  White    Male
# 32560   52      Self-emp-inc  287927    Exec-managerial  White  Female
#
#        capital-gain  capital-loss  hours-per-week salary   education_summary  \
# ...

# %%
df_c.head()
# Out:
#    age         workclass  fnlwgt         occupation   race     sex  \
# 0   39         State-gov   77516       Adm-clerical  White    Male
# 1   50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2   38           Private  215646  Handlers-cleaners  White    Male
# 3   53           Private  234721  Handlers-cleaners  Black    Male
# 4   28           Private  338409     Prof-specialty  Black  Female
#
#    capital-gain  capital-loss  hours-per-week salary   education_summary  \
# 0          2174             0              40  <=50K    high_level_grade
# 1             0             0              13  <=50K    high_level_grade
# 2             0             0              40  <=50K  medium_level_grade
# 3             0             0              40  <=50K     low_level_grade
# 4             0             0              40  <=50K    high_level_grade
#
#   marital_status_summary native_country_summary
# 0              unmarried                     US
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %%
df_new=df_c.copy()
df_new
# Out:
#        age         workclass  fnlwgt         occupation   race     sex  \
# 0       39         State-gov   77516       Adm-clerical  White    Male
# 1       50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2       38           Private  215646  Handlers-cleaners  White    Male
# 3       53           Private  234721  Handlers-cleaners  Black    Male
# 4       28           Private  338409     Prof-specialty  Black  Female
# ...    ...               ...     ...                ...    ...     ...
# 32556   27           Private  257302       Tech-support  White  Female
# 32557   40           Private  154374  Machine-op-inspct  White    Male
# 32558   58           Private  151910       Adm-clerical  White  Female
# 32559   22           Private  201490       Adm-clerical  White    Male
# 32560   52      Self-emp-inc  287927    Exec-managerial  White  Female
#
#        capital-gain  capital-loss  hours-per-week salary   education_summary  \
# ...

# %%
df_new.reset_index(inplace=True)

# %%
df_new.salary.map({"<=50K":0, ">50K":1})
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 29969    0
# 29970    1
# 29971    0
# 29972    0
# 29973    1
# Name: salary, Length: 29974, dtype: int64

# %%
df_new.salary.value_counts()
# Out:
# <=50K    22524
# >50K      7450
# Name: salary, dtype: int64

# %%
df_new_d = pd.get_dummies(data = df_new, drop_first=True)
df_new_d
# Out:
#        level_0  index  age  fnlwgt  capital-gain  capital-loss  \
# 0            0      0   39   77516          2174             0
# 1            1      1   50   83311             0             0
# 2            2      2   38  215646             0             0
# 3            3      3   53  234721             0             0
# 4            4      4   28  338409             0             0
# ...        ...    ...  ...     ...           ...           ...
# 29969    29969  32556   27  257302             0             0
# 29970    29970  32557   40  154374             0             0
# 29971    29971  32558   58  151910             0             0
# 29972    29972  32559   22  201490             0             0
# 29973    29973  32560   52  287927         15024             0
#
#        hours-per-week  workclass_Local-gov  workclass_Private  \
# 0                  40                    0                  0
# 1                  13                    0                  0
# ...

# %%
df_new_d.shape
# Out:
# (29974, 36)

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %%
df_new_d.corr()
# Out:
#                                       level_0  index    age  fnlwgt  \
# level_0                                 1.000  1.000  0.000  -0.002
# index                                   1.000  1.000  0.000  -0.002
# age                                     0.000  0.000  1.000  -0.074
# fnlwgt                                 -0.002 -0.002 -0.074   1.000
# capital-gain                            0.001  0.001  0.082  -0.002
# capital-loss                           -0.001 -0.001  0.059  -0.011
# hours-per-week                         -0.002 -0.002  0.119  -0.019
# workclass_Local-gov                    -0.002 -0.002  0.070  -0.004
# workclass_Private                       0.006  0.006 -0.211   0.045
# workclass_Self-emp-inc                 -0.002 -0.002  0.111  -0.025
# workclass_Self-emp-not-inc             -0.007 -0.007  0.146  -0.037
# workclass_State-gov                    -0.002 -0.002  0.020  -0.012
# workclass_Without-pay                   0.010  0.010  0.016  -0.003
# ...

# %%
plt.figure(figsize=(60,80))
sns.heatmap(df_new_d.corr(), annot=True);

# %%
df_s=df_new_d.corr()[["salary_>50K"]].sort_values(by=["salary_>50K"],ascending=False)
df_s
# Out:
#                                       salary_>50K
# salary_>50K                                 1.000
# age                                         0.253
# hours-per-week                              0.247
# capital-gain                                0.222
# sex_Male                                    0.216
# occupation_Exec-managerial                  0.215
# occupation_Prof-specialty                   0.185
# capital-loss                                0.152
# workclass_Self-emp-inc                      0.138
# race_White                                  0.086
# native_country_summary_US                   0.035
# workclass_Self-emp-not-inc                  0.030
# workclass_Local-gov                         0.029
# occupation_Protective-serv                  0.026
# occupation_Tech-support                     0.023
# occupation_Sales                            0.015
# race_Asian-Pac-Islander                     0.012
# workclass_State-gov                         0.011
# ...

# %%
plt.figure(figsize=(2, 7))

sns.heatmap(df_s, annot= True, cmap="coolwarm", vmin = -1, vmax=1);

# %%
plt.figure(figsize=(12,8))
df_new_d.corr()["salary_>50K"].sort_values().plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
